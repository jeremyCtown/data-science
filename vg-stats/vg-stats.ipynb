# %%
# global installs for required packages, very common to see these aliased as so
import pandas as pd
import numpy as np
from datetime import date

# %%
# read in the weather data file with pandas, df is common name for reading in a file
df = pd.read_csv('./videogamesales.zip')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ## Q1: Which company is the most common video game publisher?
# ### Answer: Electronic Arts (1351 titles)

# %%
publisher = df.groupby(df.Publisher)
popular_publisher = publisher['Publisher'].count()
popular_publisher.sort_values(ascending=False)
# Out:
# Publisher
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Eidos Interactive                          198
# Midway Games                               198
# 505 Games                                  192
# ...

# %% [markdown]
# ## Q2: What’s the most common platform?
# ### Answer: Nintendo DS with 2163 titles

# %%
platform = df.groupby(df.Platform)
popular_platform = platform['Platform'].count()
popular_platform.sort_values(ascending=False)
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %% [markdown]
# ## Q3: What about the most common genre?
# ### Answer: Action with 3316 titles

# %%
genre = pd.DataFrame(df['Genre']).groupby(df.Genre).count()
genre = genre.sort_values(['Genre'], ascending=False)
genre.head()
# Out:
#               Genre
# Genre
# Action         3316
# Sports         2346
# Misc           1739
# Role-Playing   1488
# Shooter        1310

# %% [markdown]
# ## Q4: What are the top 20 highest grossing games?
# ### Answer: See printout

# %%
highest_gross = df.sort_values(['Global_Sales'], ascending=False)
highest_gross.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ## Q5: For North American video game sales, what’s the median?
# ### Answer: See printout

# %%
df['NA_Sales'].median()
# Out:
# 0.08

# %%
df[(df['NA_Sales'] > 0.079) & (df['NA_Sales'] < 0.081)].head(11)
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
# 3806  3808                                            F1 2009      PSP
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ## Q6: For the top-selling game of all time, how many standard deviations above the mean are its sales for North America?
# ### Answer: 50.48

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
std_devs_from_mean = ((41.49-0.264667)/0.816683)
print std_devs_from_mean
# or 
(pd.DataFrame(df['NA_Sales']).max() - pd.DataFrame(df['NA_Sales']).mean()) / pd.DataFrame(df['NA_Sales']).std()
# Out:
# 50.478990012
# NA_Sales    50.478988
# dtype: float64

# %% [markdown]
# ## Q7: The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?
# ## Answer:

# %%
# df['Platform'] = df['Platform'].apply(lambda x: 1 if x == 'Wii' else 0)
# wii_platform_sales = df[['Platform', 'Global_Sales']].groupby(df.Platform)
df.head()

# pd.DataFrame(df.Platform['Wii', 'Global_Sales'])
# .sum(df.Global_Sales).count().sort_values('Platform', ascending=False)
# Out:
#    Rank                      Name  Platform    Year         Genre Publisher  \
# 0     1                Wii Sports         0  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.         0  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii         0  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort         0  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue         0  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Wii
# 0     41.49     29.02      3.77         8.46         82.74    1
# 1     29.08      3.58      6.81         0.77         40.24    0
# 2     15.85     12.88      3.79         3.31         35.82    1
# 3     15.75     11.01      3.28         2.96         33.00    1
# 4     11.27      8.89     10.22         1.00         31.37    0

# %%
highest_gross = df.sort_values(['Global_Sales'], ascending=False)
highest_gross.head(20)

genre = pd.DataFrame(df['Genre']).groupby(df.Genre).count()
genre = genre.sort_values(['Genre'], ascending=False)
genre.head()

# %%
# Out:
# NA_Sales    50.478988
# dtype: float64

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
